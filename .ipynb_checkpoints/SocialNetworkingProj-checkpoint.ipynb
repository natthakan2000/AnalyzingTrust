# %%
import networkx as nx
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from community import community_louvain
import numpy as np
import community
import random

# %% [markdown]
# **Structural Analysis**

# %%
G = snap.LoadEdgeListStr(snap.TNGraph, "/Users/natthakan/muic/AnalyzingTrust/soc-google-plus/soc-google-plus.txt", 0, 1)

print("Number of Nodes: %d" % G.GetNodes())

print("Number of Edges: %d" % G.GetEdges())

numNodes = G.GetNodes()
numEdges = G.GetEdges()
temp = (numNodes*(numNodes - 1))
print("Density of graph:",(numEdges/temp))

# a = list(range(1, 211188))
# print(a)
# print(G.GetBfsEffDiam(numNodes, a, True))

Cf, CfVec = G.GetClustCf(True, -1)
print("Average Clustering Coefficient: %f" % (Cf))

diam = G.GetBfsFullDiam(numNodes, True)
print("Diameter of graph:",diam)

# %% [markdown]
# **PowerLaw and Degree Distribution**

# %%
G = snap.LoadEdgeListStr(snap.TNGraph, "/Users/natthakan/muic/AnalyzingTrust/soc-google-plus/soc-google-plus.txt", 0, 1)
degToVec = snap.TIntPrV()
snap.GetInDegCnt(G, degToVec)
hist = np.dstack([[pair.GetVal1(), pair.GetVal2()] for pair in degToVec])[0]
plt.loglog(hist[0], hist[1],label = 'GooglePlus')
plt.legend()
plt.title('degree distribution')
plt.xlabel('degree')
plt.ylabel('nodes')
plt.show();
#I don't know how to plot bargraph version

# %%
degToVec = snap.TIntPrV()
In = snap.GetInDegCnt(G, degToVec)
Out = snap.GetOutDegCnt(G, degToVec)
# plt.figure(figsize=(4,4))
# plt.plot(In,Out,'ro',markersize=0.25)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# <snap.TIntPrV; proxy of <Swig Object of type 'TVec< TPair< TInt,TInt >,int > *' at 0x122bf8480> >

# %%
degToVec = snap.TIntPrV()
snap.GetInDegCnt(G, degToVec)
hist = np.dstack([[pair.GetVal1(), pair.GetVal2()] for pair in degToVec])[0]
plt.loglog(hist[0], hist[1])
plt.xlabel('in-node degree')
plt.ylabel('in-node count')
plt.title("11. distribution of in-degree nodes in the network on a log-log scale")
plt.show();

# %% [markdown]
# **Check Rich Club Effect**

# %%
graph = nx.DiGraph()
epi_csv = pd.read_csv(r"/Users/natthakan/muic/AnalyzingTrust/soc-google-plus/soc-google-plus.txt",delimiter=' ')
epi_csv.columns = ['From','To','Weight']
epi_csv.head()
for index,row in epi_csv.iterrows():
    graph.add_edges_from([(row[0],row[1])],weight = row[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-977a9fe05063> in <module>
#       1 graph = nx.DiGraph()
#       2 epi_csv = pd.read_csv(r"/Users/natthakan/muic/AnalyzingTrust/soc-google-plus/soc-google-plus.txt",delimiter=' ')
# ----> 3 epi_csv.columns = ['From','To','Weight']
#       4 epi_csv.head()
#       5 for index,row in epi_csv.iterrows():
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
# ...
